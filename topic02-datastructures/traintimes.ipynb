# %%
from xml.dom.minidom import parseString
import requests
import csv

# This is a simple example of how to get data from the Irish Rail API

retrieveTags=['TrainStatus',
            'TrainLatitude',
            'TrainLongitude',
            'TrainCode',
            'TrainDate',
            'PublicMessage',
            'Direction'
            ]

url = "http://api.irishrail.ie/realtime/realtime.asmx/getCurrentTrainsXML"
page = requests.get(url)

doc = parseString(page.content)
# check it works
# newl='' gets rid of the new lines when printing
print (doc.toprettyxml(newl='')) #output to console

# store the xml in a file
with open("trainxml.xml","w") as xmlfp:
    doc.writexml(xmlfp)


# I had an issue with blank lines in the file so found solution at
# https://stackoverflow.com/questions/3348460/csv-file-written-with-python-has-blank-lines-between-each-row
# adding the newline= '' parameter
with  open('week02_train.csv', mode='w', newline='') as train_file:
    train_writer = csv.writer(train_file, delimiter='\t', quotechar='"', quoting=csv.QUOTE_MINIMAL)

    objTrainPositionsNodes = doc.getElementsByTagName("objTrainPositions")
    for objTrainPositionsNode in objTrainPositionsNodes:
        #traincodenode = objTrainPositionsNode.getElementsByTagName("TrainCode").item(0)
        #traincode = traincodenode.firstChild.nodeValue.strip()
        #print (traincode)

        # now lets get everything
        dataList = []
        for retrieveTag in retrieveTags:
            datanode = objTrainPositionsNode.getElementsByTagName(retrieveTag).item(0)
            dataList.append(datanode.firstChild.nodeValue.strip())
        
        # instead of printing this it'll be possible to output to another format
        #print (dataList)
        # for example a CSV file  
        train_writer.writerow(dataList)
# Out:
# <?xml version="1.0" ?><ArrayOfObjTrainPositions xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema" xmlns="http://api.irishrail.ie/realtime/">
#   	<objTrainPositions>
#     		<TrainStatus>N</TrainStatus>
#     		<TrainLatitude>53.2043</TrainLatitude>
#     		<TrainLongitude>-6.10046</TrainLongitude>
#     		<TrainCode>B134</TrainCode>
#     		<TrainDate>10 Apr 2025</TrainDate>
#     		<PublicMessage>B134\nBray to Greystones\nExpected Departure 00:25</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.4855</TrainLatitude>
#     		<TrainLongitude>-6.15134</TrainLongitude>
#     		<TrainCode>D841</TrainCode>
#     		<TrainDate>09 Apr 2025</TrainDate>
#     		<PublicMessage>D841\n23:40 - Grand Canal Dock to Dundalk (0 mins late)\nDeparted Donabate next stop Rush and Lusk</PublicMessage>
#     		<Direction>To Dundalk</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.712</TrainLatitude>
#     		<TrainLongitude>-6.33538</TrainLongitude>
#     		<TrainCode>D839</TrainCode>
#     		<TrainDate>09 Apr 2025</TrainDate>
#     		<PublicMessage>D839\n22:47 - Grand Canal Dock to Dundalk (2 mins late)\nDeparted Drogheda next stop Dundalk</PublicMessage>
#     		<Direction>To Dundalk</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>T</TrainStatus>
#     		<TrainLatitude>53.2043</TrainLatitude>
#     		<TrainLongitude>-6.10046</TrainLongitude>
#     		<TrainCode>E134</TrainCode>
#     		<TrainDate>09 Apr 2025</TrainDate>
#     		<PublicMessage>E134\n23:05 - Malahide to Bray(-1 mins late)\nTERMINATED Bray at 00:18</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>T</TrainStatus>
#     		<TrainLatitude>53.3223</TrainLatitude>
#     		<TrainLongitude>-6.52356</TrainLongitude>
#     		<TrainCode>D426</TrainCode>
#     		<TrainDate>09 Apr 2025</TrainDate>
#     		<PublicMessage>D426\n23:30 - Grand Canal Dock to Hazelhatch(0 mins late)\nTERMINATED Hazelhatch at 00:16</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>T</TrainStatus>
#     		<TrainLatitude>53.3531</TrainLatitude>
#     		<TrainLongitude>-6.24591</TrainLongitude>
#     		<TrainCode>E701</TrainCode>
#     		<TrainDate>09 Apr 2025</TrainDate>
#     		<PublicMessage>E701\n23:20 - Greystones to Dublin Connolly(-2 mins late)\nTERMINATED Dublin Connolly at 00:17</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>T</TrainStatus>
#     		<TrainLatitude>53.3531</TrainLatitude>
#     		<TrainLongitude>-6.24591</TrainLongitude>
#     		<TrainCode>E704</TrainCode>
#     		<TrainDate>09 Apr 2025</TrainDate>
#     		<PublicMessage>E704\n23:55 - Howth to Dublin Connolly(-2 mins late)\nTERMINATED Dublin Connolly at 00:18</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>T</TrainStatus>
#     		<TrainLatitude>53.3891</TrainLatitude>
#     		<TrainLongitude>-6.07401</TrainLongitude>
#     		<TrainCode>E951</TrainCode>
#     		<TrainDate>09 Apr 2025</TrainDate>
#     		<PublicMessage>E951\n22:52 - Greystones to Howth(1 mins late)\nTERMINATED Howth at 00:19</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
# </ArrayOfObjTrainPositions>
